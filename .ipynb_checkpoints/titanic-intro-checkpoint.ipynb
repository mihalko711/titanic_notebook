# %% [markdown]
# # FOR  KAGGLE

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train_path = '/kaggle/input/titanic/train.csv'
test_path = '/kaggle/input/titanic/test.csv'
example_path = '/kaggle/input/titanic/gender_submission.csv'

# %% [markdown]
# # FOR OWN USAGE

# %%
train_path = 'data/train.csv'
test_path = 'data/test.csv'
example_path = 'data/gender_submission.csv'

# %% [markdown]
# # Imports

# %%
import numpy as  np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid", palette="muted", context="notebook")

# %% [markdown]
# # Задача
#
#
# Имеется датасет с информацией о пассажирах Титаника со следующими данными о каждом пассажире:
# 1. `PassengerId` - идентификатор пассажира внутри датасета
# 2. `Survived` - целевая переменная, выжил/не выжил при кораблекрушении
# 3. `Pclass` - класс каюты
# 4. `Name` - полное имя, содержит титутлы
# 5. `Sex` - пол
# 6. `Age` - возраст
# 7. `SibSp` - родственники(кроме родителей и детей) на корабле
# 8. `Parch` - кол-во родителей и детей на корабле
# 9. `Ticket` - идентификатор билета
# 10. `Fare` - цена билета
# 11. `Cabin` - номер кабины
# 12. `Embarked` - место, откуда соверашалась посадка
#
# Как можно понять из описанных данных - предсказывать нужно выживаемость в катастрофе, в качестве метрики используется `accuracy`

# %% [markdown]
# # Data loading and check

# %%
data_train = pd.read_csv(train_path)
data_test = pd.read_csv(test_path)
example_submission = pd.read_csv(example_path)

# %%
print(f"'Train columnns: {', '.join(str(el) for el in data_train.columns)}")
print(data_train.info())
data_train.head(5)
# Out:
# 'Train columnns: PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# ...

# %%
print(f"'Test columnns: {', '.join(str(el) for el in data_test.columns)}")
print(data_test.info())
data_test.head(5)
# Out:
# 'Test columnns: PassengerId, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB
# None
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# ...

# %% [markdown]
# ## Missing values and data types

# %%
data_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
missing_train = data_train.isna().sum()
missing_train_relatively = missing_train / len(data_train)
missing_train_summary = pd.DataFrame({
    'missing_count' : missing_train,
    'missing_fraction' : missing_train_relatively.round(2)
                                    
})

missing_test = data_test.isna().sum()
missing_test_relatively = missing_test / len(data_test)
missing_test_summary = pd.DataFrame({
    'missing_count' : missing_test,
    'missing_fraction' : missing_test_relatively.round(2)
                                    
})


print(f"Train missing:\n {missing_train_summary}")
print(f"Test missing:\n {missing_test_summary}")
# Out:
# Train missing:
#               missing_count  missing_fraction
# PassengerId              0              0.00
# Survived                 0              0.00
# Pclass                   0              0.00
# Name                     0              0.00
# Sex                      0              0.00
# Age                    177              0.20
# SibSp                    0              0.00
# Parch                    0              0.00
# Ticket                   0              0.00
# Fare                     0              0.00
# Cabin                  687              0.77
# Embarked                 2              0.00
# Test missing:
#               missing_count  missing_fraction
# PassengerId              0              0.00
# Pclass                   0              0.00
# Name                     0              0.00
# Sex                      0              0.00
# Age                     86              0.21
# SibSp                    0              0.00
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
numerical_columns_continuous = data_train.select_dtypes(include = 'float64').columns.tolist()
numerical_columns_discrete = data_train.select_dtypes(include = 'int64').columns.tolist()
categorical_columns = data_train.select_dtypes(include = 'object').columns.tolist()

# %% [markdown]
# ## Numerical

# %% [markdown]
# ### Continuous

# %%
fig, ax = plt.subplots(3, len(numerical_columns_continuous), figsize = (10 * len(numerical_columns_continuous), 10))

for a, feature in zip(ax[0], numerical_columns_continuous):
    sns.violinplot(data = data_train, x = feature, ax = a)
for a, feature in zip(ax[1], numerical_columns_continuous):
    sns.boxplot(data = data_train, x = feature, ax = a)
for a, feature in zip(ax[2], numerical_columns_continuous):
    sns.ecdfplot(data = data_train, x = feature, ax = a)

fig.suptitle(f'Непрерывные числовые признаки на тренировочной выборке')
plt.show()

fig, ax = plt.subplots(3, len(numerical_columns_continuous), figsize = (10 * len(numerical_columns_continuous), 10))

for a, feature in zip(ax[0], numerical_columns_continuous):
    sns.violinplot(data = data_test, x = feature, ax = a)
for a, feature in zip(ax[1], numerical_columns_continuous):
    sns.boxplot(data = data_test, x = feature, ax = a)
for a, feature in zip(ax[2], numerical_columns_continuous):
    sns.ecdfplot(data = data_test, x = feature, ax = a)
    
fig.suptitle(f'Непрерывные числовые признаки на тестовой выборке')
plt.show()

# %% [markdown]
# ### Discrete

# %%
fig, ax = plt.subplots(1, len(numerical_columns_discrete[1:]), figsize = (5 * len(numerical_columns_discrete[1:]), 5))

for a, feature in zip(ax, numerical_columns_discrete[1:]):
    sns.countplot(data = data_train, x = feature, ax = a, hue = feature)

fig.suptitle(f'Дискретные числовые признаки на тренировочной выборке')
plt.show()

fig, ax = plt.subplots(1, len(numerical_columns_discrete[1:]), figsize = (5 * len(numerical_columns_discrete[1:]), 5))

for a, feature in zip(ax[1:], numerical_columns_discrete[2:]):
    sns.countplot(data = data_test, x = feature, ax = a, hue = feature)

fig.suptitle(f'Дискретные числовые признаки на тестовой выборке')
plt.show()

# %% [markdown]
# ## Categorical

# %%
print(f"all categorical features: {', '.join(categorical_columns)}")
new_categorical = ['Sex', 'Embarked']

fig, ax = plt.subplots(1, len(new_categorical), figsize = (5 * len(new_categorical), 5))

for a, feature in zip(ax, new_categorical):
    sns.countplot(data = data_train, x = feature, ax = a, hue = feature)

fig.suptitle(f'Категориальные признаки на тренировочной выборке')
plt.show()

fig, ax = plt.subplots(1, len(new_categorical), figsize = (5 * len(new_categorical), 5))

for a, feature in zip(ax, new_categorical):
    sns.countplot(data = data_test, x = feature, ax = a, hue = feature)

fig.suptitle(f'Категориальные признаки на тестовой выборке')
plt.show()
# Out:
# all categorical features: Name, Sex, Ticket, Cabin, Embarked

# %% [markdown]
# ## Relation between features

# %% [markdown]
# ### Heatmaps on categorical

# %%
new_categorical_columns = numerical_columns_discrete[1:] + new_categorical
n = len(new_categorical_columns)
fig, ax = plt.subplots(n, n - 1, figsize = ((n - 1) * 5, n * 5))


for _ in ax:
    for __ in _:
        __.set_visible(False)
for first_id, _ in zip(range(n), ax):
    for second_id, __ in zip(range(first_id + 1, n), _):
        ct = pd.crosstab(data_train[new_categorical_columns[first_id]], data_train[new_categorical_columns[second_id]])
        sns.heatmap(ct, ax = __, annot = True, fmt="d", cmap="YlGnBu")
        __.set_visible(True)

fig.suptitle(f'Перекрестные таблицы для категориальных признаков на тренировочной выборке')
plt.show()

n = len(new_categorical_columns[1:])
fig, ax = plt.subplots(n, n - 1, figsize = ((n - 1) * 5, n * 5))


for _ in ax:
    for __ in _:
        __.set_visible(False)
for first_id, _ in zip(range(n), ax):
    for second_id, __ in zip(range(first_id + 1, n), _):
        ct = pd.crosstab(data_test[new_categorical_columns[1:][first_id]], data_test[new_categorical_columns[1:][second_id]])
        sns.heatmap(ct, ax = __, annot = True, fmt="d", cmap="YlGnBu")
        __.set_visible(True)

fig.suptitle(f'Перекрестные таблицы для категориальных признаков на тестовой выборке')
plt.show()

# %% [markdown]
# ### Countplots with hue on other category

# %%
new_categorical_columns = numerical_columns_discrete[1:] + new_categorical
n = len(new_categorical_columns)
fig, ax = plt.subplots(n, n - 1, figsize = ((n - 1) * 5, n * 5))


for _ in ax:
    for __ in _:
        __.set_visible(False)
for first_id, _ in zip(range(n), ax):
    for second_id, __ in zip(range(first_id + 1, n), _):
        sns.countplot(data_train, x = new_categorical_columns[first_id], hue = new_categorical_columns[second_id], ax = __)
        __.set_visible(True)

fig.suptitle(f'Подсчет для категориальных признаков на тренировочной выборке')
plt.show()

n = len(new_categorical_columns[1:])
fig, ax = plt.subplots(n, n - 1, figsize = ((n - 1) * 5, n * 5))


for _ in ax:
    for __ in _:
        __.set_visible(False)
for first_id, _ in zip(range(n), ax):
    for second_id, __ in zip(range(first_id + 1, n), _):
        sns.countplot(data_test, x = new_categorical_columns[1:][first_id], hue = new_categorical_columns[1:][second_id], ax = __)
        __.set_visible(True)

fig.suptitle(f'Подсчет для категориальных признаков на тестовой выборке')
plt.show()

# %% [markdown]
# ### Categorical X Continuos(boxplot)

# %%
new_categorical_columns = numerical_columns_discrete[1:] + new_categorical

n = len(new_categorical_columns)
m = len(numerical_columns_continuous)
fig, ax = plt.subplots(m, n, figsize = (n * 5, m * 5))
        
for first_id, _ in zip(range(m), ax):
    for second_id, __ in zip(range(n), _):
        sns.boxplot(data = data_train, x = numerical_columns_continuous[first_id], hue = new_categorical_columns[second_id], ax = __)
        __.set_visible(True)

fig.suptitle(f'Числовые с делением по категориальным на тренировочной выборке')
plt.show()

n = len(new_categorical_columns[1:])
m = len(numerical_columns_continuous)
fig, ax = plt.subplots(m, n, figsize = (n * 5, m * 5))
        
for first_id, _ in zip(range(m), ax):
    for second_id, __ in zip(range(n), _):
        sns.boxplot(data = data_test, x = numerical_columns_continuous[first_id], hue = new_categorical_columns[1:][second_id], ax = __)
        __.set_visible(True)

fig.suptitle(f'Числовые с делением по категориальным на тестовой выборке')
plt.show()

# %% [markdown]
# ### Categorical X Continuos(violinplot)

# %%
new_categorical_columns = numerical_columns_discrete[1:] + new_categorical

n = len(new_categorical_columns)
m = len(numerical_columns_continuous)
fig, ax = plt.subplots(m, n, figsize = (n * 5, m * 5))
        
for first_id, _ in zip(range(m), ax):
    for second_id, __ in zip(range(n), _):
        sns.violinplot(data = data_train, x = numerical_columns_continuous[first_id], hue = new_categorical_columns[second_id], ax = __)
        __.set_visible(True)

fig.suptitle(f'Числовые с делением по категориальным на тренировочной выборке')
plt.show()

n = len(new_categorical_columns[1:])
m = len(numerical_columns_continuous)
fig, ax = plt.subplots(m, n, figsize = (n * 5, m * 5))
        
for first_id, _ in zip(range(m), ax):
    for second_id, __ in zip(range(n), _):
        sns.violinplot(data = data_test, x = numerical_columns_continuous[first_id], hue = new_categorical_columns[1:][second_id], ax = __)
        __.set_visible(True)

fig.suptitle(f'Числовые с делением по категориальным на тестовой выборке')
plt.show()

# %% [markdown]
# ### Numerical X Numerical

# %%
sns.jointplot(data = data_train, x = 'Fare', y = 'Age', hue = 'Survived', kind = 'hist')
sns.jointplot(data = data_test, x = 'Fare', y = 'Age', kind = 'hist')

sns.jointplot(data = data_train, x = 'Fare', y = 'Age', hue = 'Survived', kind = 'kde')
sns.jointplot(data = data_test, x = 'Fare', y = 'Age', kind = 'kde')

sns.jointplot(data = data_train, x = 'Fare', y = 'Age', hue = 'Survived', kind = 'scatter')
sns.jointplot(data = data_test, x = 'Fare', y = 'Age', kind = 'scatter')

sns.pairplot(data = data_train.drop('PassengerId', axis = 1), hue = 'Survived')
sns.pairplot(data = data_test.drop('PassengerId', axis = 1))

# %% [markdown]
# ## Work with target

# %% [markdown]
# ### Categorical with target

# %%
n = len(new_categorical_columns[1:])
fig, axs = plt.subplots(1, n, figsize = (n * 5, 5))

for category, ax in zip(new_categorical_columns[1:], axs):
    sns.countplot(data = data_train, x = category, hue = 'Survived', ax = ax)

# %% [markdown]
# ### Numerical with target

# %%
new_categorical_columns = numerical_columns_discrete[1:] + new_categorical

m = len(numerical_columns_continuous)
fig, axs = plt.subplots(2, m, figsize = (m * 5, 5))
        
for first_id, ax in zip(range(m), axs[0]):
        sns.violinplot(data = data_train, x = numerical_columns_continuous[first_id], hue = 'Survived', ax = ax)

for first_id, ax in zip(range(m), axs[1]):
        sns.boxplot(data = data_train, x = numerical_columns_continuous[first_id], hue = 'Survived', ax = ax)

plt.show()
sns.scatterplot(data = data_train, x='Fare', y='Age', hue = 'Survived')
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(data_train[['Fare', 'Age', 'Pclass', 'SibSp', 'Parch', 'Survived']].corr(), annot=True, cmap="coolwarm")
data_train[['Fare', 'Age', 'Pclass', 'SibSp', 'Parch', 'Survived']].corr()['Survived'].sort_values(ascending=False)
# Out:
# Survived    1.000000
# Fare        0.257307
# Parch       0.081629
# SibSp      -0.035322
# Age        -0.077221
# Pclass     -0.338481
# Name: Survived, dtype: float64

# %% [markdown]
# ## Conclusion
